# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import sys
sys.path.append("..")

from positional_encoding import PositionalEncoding

# %%
D = 8
positionalEncoding = PositionalEncoding(D)

# %%
pe = positionalEncoding.pe.squeeze().detach()

_, ax = plt.subplots(1, 1, figsize=(20, 5))
ax.set_title("pe")
ax.plot(pe[:2000, 2:])
plt.show()
